# %%
print ("hello world")
print (2+ 3)
print (3 - 10)
print ("3-10")
print( 3*4)
# Out:
# hello world
# 5
# -7
# 3-10
# 12

# %% [markdown]
# Michal Fink

# %%
# other arithemetic 
print(2**3) #exponents
print(35/ 8 ) # division
print (35 // 8) # integer division
# Out:
# 8
# 4.375
# 4

# %%
import statistics
print(statistics.mean([1,3,5,7,9]))
# Out:
# 5

# %%
import statistics as stats
import pandas as pd 
import matplotlib as plt
